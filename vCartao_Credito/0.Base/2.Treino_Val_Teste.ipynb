# %% [markdown]
# # Objetivo
#
# Separação da base em três conjuntos de dados: treino, validação e teste. Como não temos informação de temporalidade da variável resposta (por exemplo, chance do cliente ser churn no pŕoximo mês ou nos pŕoximos 2 meses, etc), admitimos que ela é definida como o cliente é churn ou não hoje. Dessa forma, as probabilidades a serem calculadas pelo modelo nos informará qual é a incerteza (certeza) do cliente ser churn hoje.

# %% [markdown]
# # Pacotes

# %%
#!pip install scikit-learn

# %%
from deltalake import DeltaTable, write_deltalake
from sklearn.model_selection import train_test_split
import pandas as pd
import os

# %% [markdown]
# # Leitura da base de dados

# %%
dados_full = DeltaTable('tmp/full_data').to_pandas()
dados_full.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status     Income_Category Card_Category  \
# 0     High School        Married   3. >= 60k & < 80k          Blue
# 1        Graduate         Single             1.< 40k          Blue
# 2        Graduate        Married  4. >= 80k & < 120k          Blue
# 3     High School        Unknown             1.< 40k          Blue
# 4      Uneducated        Married   3. >= 60k & < 80k          Blue
#
#    Months_on_book  ...  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0              39  ...          11914.0                 1.335
# 1              44  ...           7392.0                 1.541
# 2              36  ...           3418.0                 2.594
# 3              34  ...            796.0                 1.405
# 4              21  ...           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0             1144              42                1.625
# 1             1291              33                3.714
# 2             1887              20                2.333
# 3             1171              20                2.333
# 4              816              28                2.500
#
#    Avg_Utilization_Ratio  Education_Level_v1  Education_Level_v2        vfm  \
# 0                  0.061       2.High School       2.High School  27.238095
# 1                  0.105          4.Graduate          3.Graduate  39.121212
# 2                  0.000          4.Graduate          3.Graduate  94.350000
# 3                  0.760       2.High School       2.High School  58.550000
# 4                  0.000        1.Uneducated        1.Uneducated  29.142857
#
#        pmcc
# 0  0.007512
# 1  0.013031
# 2  0.046006
# 3  0.029455
# 4  0.014419
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Percentuais de treino, validação e teste
#
# - Nesta etapa, não droparemos nenhuma coluna.

# %%
X = dados_full.drop(['Attrition_Flag'], axis = 1)
y = dados_full['Attrition_Flag']

# %%
X.columns
# Out:
# Index(['CLIENTNUM', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Education_Level_v1', 'Education_Level_v2', 'vfm', 'pmcc'],
#       dtype='object')

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=.15, stratify=y, random_state=1234)
X_treino, X_val, y_treino, y_val = train_test_split(X_treino, y_treino, test_size=.15, stratify=y_treino, random_state=1234)

# %%
X_treino.shape, X_val.shape, X_teste.shape, y_treino.shape, y_val.shape, y_teste.shape
# Out:
# ((7315, 24), (1292, 24), (1520, 24), (7315,), (1292,), (1520,))

# %% [markdown]
# ## Volumetria absoluta e percentual de churn

# %% [markdown]
# ### Treino

# %%
y_treino.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    6140
# Attrited Customer    1175
# Name: count, dtype: int64

# %%
y_treino.value_counts()/y_treino.shape[0]
# Out:
# Attrition_Flag
# Existing Customer    0.839371
# Attrited Customer    0.160629
# Name: count, dtype: float64

# %%
dados_treino = pd.concat([X_treino, y_treino], axis = 1)
dados_treino['type'] = 'Treino'
dados_treino.head()
# Out:
#       CLIENTNUM  Customer_Age Gender  Dependent_count Education_Level  \
# 3774  713904708            40      F                3        Graduate
# 2983  778908783            52      M                3         College
# 1238  756013833            57      M                3       Doctorate
# 5088  718994583            48      F                2         College
# 1852  721344858            26      M                0      Uneducated
#
#      Marital_Status     Income_Category Card_Category  Months_on_book  \
# 3774        Married             1.< 40k          Blue              36
# 2983        Married  4. >= 80k & < 120k          Blue              33
# 1238        Married  4. >= 80k & < 120k          Blue              50
# 5088         Single             1.< 40k          Blue              35
# 1852         Single             1.< 40k          Blue              13
#
#       Total_Relationship_Count  ...  Total_Trans_Amt  Total_Trans_Ct  \
# 3774                         6  ...             4926              85
# 2983                         3  ...             1427              25
# 1238                         3  ...             1806              38
# 5088                         3  ...             4777              69
# 1852                         4  ...             2192              36
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  Education_Level_v1  \
# 3774                0.635                  0.256          4.Graduate
# 2983                0.667                  0.037           3.College
# 1238                0.727                  0.412         6.Doctorate
# 5088                0.917                  0.567           3.College
# 1852                0.440                  0.202        1.Uneducated
#
#       Education_Level_v2        vfm      pmcc     Attrition_Flag    type
# 3774          3.Graduate  57.952941  0.054141  Existing Customer  Treino
# 2983          3.Graduate  57.080000  0.004285  Existing Customer  Treino
# 1238     4.Post-Graduate  47.526316  0.033282  Existing Customer  Treino
# 5088          3.Graduate  69.231884  0.276774  Existing Customer  Treino
# 1852        1.Uneducated  60.888889  0.081657  Existing Customer  Treino
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Validação

# %%
y_val.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    1084
# Attrited Customer     208
# Name: count, dtype: int64

# %%
y_val.value_counts()/y_val.shape[0]
# Out:
# Attrition_Flag
# Existing Customer    0.839009
# Attrited Customer    0.160991
# Name: count, dtype: float64

# %%
dados_val = pd.concat([X_val, y_val], axis = 1)
dados_val['type'] = 'Validacao'
dados_val.head()
# Out:
#       CLIENTNUM  Customer_Age Gender  Dependent_count Education_Level  \
# 1459  712281183            55      M                4        Graduate
# 2492  809620833            35      F                3         Unknown
# 5958  711527508            46      F                3     High School
# 8922  717658758            49      M                4        Graduate
# 7746  719797758            56      F                1     High School
#
#      Marital_Status    Income_Category Card_Category  Months_on_book  \
# 1459        Married         5. >= 120k          Blue              36
# 2492         Single          0.Unknown          Blue              30
# 5958        Married  2. >= 40k & < 60k          Blue              34
# 8922         Single         5. >= 120k        Silver              36
# 7746         Single            1.< 40k          Blue              36
#
#       Total_Relationship_Count  ...  Total_Trans_Amt  Total_Trans_Ct  \
# 1459                         4  ...             1425              33
# 2492                         3  ...             2314              59
# 5958                         2  ...             1794              31
# 8922                         2  ...             7962              99
# 7746                         3  ...             4922              84
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  Education_Level_v1  \
# 1459                0.650                  0.035          4.Graduate
# 2492                1.034                  0.000           0.Unknown
# 5958                0.292                  0.000       2.High School
# 8922                0.435                  0.000          4.Graduate
# 7746                0.680                  0.736       2.High School
#
#       Education_Level_v2        vfm      pmcc     Attrition_Flag       type
# 1459          3.Graduate  43.181818  0.004880  Existing Customer  Validacao
# 2492           0.Unknown  39.220339  0.020750  Existing Customer  Validacao
# 5958       2.High School  57.870968  0.017418  Attrited Customer  Validacao
# 8922          3.Graduate  80.424242  0.019223  Existing Customer  Validacao
# 7746       2.High School  58.595238  0.119862  Existing Customer  Validacao
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Teste

# %%
y_teste.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    1276
# Attrited Customer     244
# Name: count, dtype: int64

# %%
y_teste.value_counts()/y_teste.shape[0]
# Out:
# Attrition_Flag
# Existing Customer    0.839474
# Attrited Customer    0.160526
# Name: count, dtype: float64

# %%
dados_teste = pd.concat([X_teste, y_teste], axis = 1)
dados_teste['type'] = 'Teste'
dados_teste.head()
# Out:
#       CLIENTNUM  Customer_Age Gender  Dependent_count Education_Level  \
# 5240  719325783            65      M                2         Unknown
# 5110  789226683            44      M                1         Unknown
# 9254  720535008            46      M                4      Uneducated
# 3620  778340733            44      F                3         College
# 6609  714012258            44      F                2         College
#
#      Marital_Status     Income_Category Card_Category  Months_on_book  \
# 5240         Single             1.< 40k          Blue              36
# 5110        Married   3. >= 60k & < 80k          Blue              33
# 9254         Single  4. >= 80k & < 120k          Blue              36
# 3620        Married   2. >= 40k & < 60k          Blue              24
# 6609         Single             1.< 40k          Blue              34
#
#       Total_Relationship_Count  ...  Total_Trans_Amt  Total_Trans_Ct  \
# 5240                         4  ...             1909              28
# 5110                         6  ...             3878              82
# 9254                         1  ...            13764             104
# 3620                         3  ...             1950              31
# 6609                         3  ...             4122              74
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  Education_Level_v1  \
# 5240                0.474                  0.852           0.Unknown
# 5110                0.783                  0.239           0.Unknown
# 9254                0.733                  0.104        1.Uneducated
# 3620                0.938                  0.181           3.College
# 6609                0.850                  0.695           3.College
#
#       Education_Level_v2         vfm      pmcc     Attrition_Flag   type
# 5240           0.Unknown   68.178571  0.053854  Attrited Customer  Teste
# 5110           0.Unknown   47.292683  0.065037  Existing Customer  Teste
# 9254        1.Uneducated  132.346154  0.109321  Existing Customer  Teste
# 3620          3.Graduate   62.903226  0.019129  Existing Customer  Teste
# 6609          3.Graduate   55.702703  0.141416  Existing Customer  Teste
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Une bases e salva em uma delta table

# %%
dados_segmentados = pd.concat([dados_treino, dados_val, dados_teste], axis=0)
dados_segmentados.head()
# Out:
#       CLIENTNUM  Customer_Age Gender  Dependent_count Education_Level  \
# 3774  713904708            40      F                3        Graduate
# 2983  778908783            52      M                3         College
# 1238  756013833            57      M                3       Doctorate
# 5088  718994583            48      F                2         College
# 1852  721344858            26      M                0      Uneducated
#
#      Marital_Status     Income_Category Card_Category  Months_on_book  \
# 3774        Married             1.< 40k          Blue              36
# 2983        Married  4. >= 80k & < 120k          Blue              33
# 1238        Married  4. >= 80k & < 120k          Blue              50
# 5088         Single             1.< 40k          Blue              35
# 1852         Single             1.< 40k          Blue              13
#
#       Total_Relationship_Count  ...  Total_Trans_Amt  Total_Trans_Ct  \
# 3774                         6  ...             4926              85
# 2983                         3  ...             1427              25
# 1238                         3  ...             1806              38
# 5088                         3  ...             4777              69
# 1852                         4  ...             2192              36
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  Education_Level_v1  \
# 3774                0.635                  0.256          4.Graduate
# 2983                0.667                  0.037           3.College
# 1238                0.727                  0.412         6.Doctorate
# 5088                0.917                  0.567           3.College
# 1852                0.440                  0.202        1.Uneducated
#
#       Education_Level_v2        vfm      pmcc     Attrition_Flag    type
# 3774          3.Graduate  57.952941  0.054141  Existing Customer  Treino
# 2983          3.Graduate  57.080000  0.004285  Existing Customer  Treino
# 1238     4.Post-Graduate  47.526316  0.033282  Existing Customer  Treino
# 5088          3.Graduate  69.231884  0.276774  Existing Customer  Treino
# 1852        1.Uneducated  60.888889  0.081657  Existing Customer  Treino
#
# [5 rows x 26 columns]

# %%
dados_segmentados.columns
# Out:
# Index(['CLIENTNUM', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Education_Level_v1', 'Education_Level_v2', 'vfm', 'pmcc',
#        'Attrition_Flag', 'type'],
#       dtype='object')

# %%
dados_segmentados.shape
# Out:
# (10127, 26)

# %%
dados_segmentados.isnull().sum()
# Out:
# CLIENTNUM                   0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# Education_Level_v1          0
# Education_Level_v2          0
# vfm                         0
# pmcc                        0
# Attrition_Flag              0
# type                        0
# dtype: int64

# %%
os.makedirs("tmp/dados_segmentados", exist_ok=True)

# %%
write_deltalake("tmp/dados_segmentados", dados_segmentados)

# %%
DeltaTable("tmp/dados_segmentados").to_pandas()
# Out:
#        CLIENTNUM  Customer_Age Gender  Dependent_count Education_Level  \
# 0      713904708            40      F                3        Graduate
# 1      778908783            52      M                3         College
# 2      756013833            57      M                3       Doctorate
# 3      718994583            48      F                2         College
# 4      721344858            26      M                0      Uneducated
# ...          ...           ...    ...              ...             ...
# 10122  717200508            40      F                4      Uneducated
# 10123  715247508            30      F                1        Graduate
# 10124  708423933            51      M                2       Doctorate
# 10125  779686683            26      F                0   Post-Graduate
# 10126  717066408            36      M                2        Graduate
#
#       Marital_Status     Income_Category Card_Category  Months_on_book  \
# 0            Married             1.< 40k          Blue              36
# 1            Married  4. >= 80k & < 120k          Blue              33
# 2            Married  4. >= 80k & < 120k          Blue              50
# 3             Single             1.< 40k          Blue              35
# 4             Single             1.< 40k          Blue              13
# ...              ...                 ...           ...             ...
# 10122         Single           0.Unknown          Blue              32
# 10123        Married             1.< 40k          Blue              36
# 10124         Single   2. >= 40k & < 60k          Blue              40
# 10125         Single             1.< 40k          Blue              13
# 10126        Married   3. >= 60k & < 80k          Blue              36
#
#        Total_Relationship_Count  ...  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                             6  ...              85                0.635
# 1                             3  ...              25                0.667
# 2                             3  ...              38                0.727
# 3                             3  ...              69                0.917
# 4                             4  ...              36                0.440
# ...                         ...  ...             ...                  ...
# 10122                         3  ...              73                0.659
# 10123                         3  ...              37                0.609
# 10124                         3  ...              64                0.829
# 10125                         5  ...              34                0.478
# 10126                         3  ...              62                0.771
#
#        Avg_Utilization_Ratio  Education_Level_v1  Education_Level_v2  \
# 0                      0.256          4.Graduate          3.Graduate
# 1                      0.037           3.College          3.Graduate
# 2                      0.412         6.Doctorate     4.Post-Graduate
# 3                      0.567           3.College          3.Graduate
# 4                      0.202        1.Uneducated        1.Uneducated
# ...                      ...                 ...                 ...
# 10122                  0.667        1.Uneducated        1.Uneducated
# 10123                  0.150          4.Graduate          3.Graduate
# 10124                  0.000         6.Doctorate     4.Post-Graduate
# 10125                  0.575     5.Post-Graduate     4.Post-Graduate
# 10126                  0.274          4.Graduate          3.Graduate
#
#              vfm      pmcc     Attrition_Flag    type  __index_level_0__
# 0      57.952941  0.054141  Existing Customer  Treino               3774
# 1      57.080000  0.004285  Existing Customer  Treino               2983
# 2      47.526316  0.033282  Existing Customer  Treino               1238
# 3      69.231884  0.276774  Existing Customer  Treino               5088
# 4      60.888889  0.081657  Existing Customer  Treino               1852
# ...          ...       ...                ...     ...                ...
# 10122  64.849315  0.129090  Existing Customer   Teste               4517
# 10123  46.270270  0.020131  Existing Customer   Teste               1505
# 10124  50.046875  0.043735  Existing Customer   Teste               2251
# 10125  61.411765  0.059959  Existing Customer   Teste               1687
# 10126  40.967742  0.038138  Existing Customer   Teste               2625
#
# [10127 rows x 27 columns]
